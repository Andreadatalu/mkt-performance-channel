# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

file_path = 'C:\\Users\\Andrea\\Documents\\DATA\\Mid-bootcamp project\\Datasets\\LIA_customer_clean.csv'
data = pd.read_csv(file_path)
display(data.shape)
data.head()
# Out:
# (996, 12)
#    age gender              city   product  price  promotion  final_price  \
# 0   25      F  Ciudad de México      Rubí   1900        0.0         1900
# 1   26      F       Guadalajara      Rubí   1900        0.0         1900
# 2   43      F    Aguascalientes      Rubí   1900        0.0         1900
# 3   29      F       Guadalajara  Diamante   2800        0.1         2520
# 4   28      F          San Luis  Diamante   2800        0.3         1960
#
#    profit sales_channel  pd_day  pd_month  pd_year
# 0  1596.0    Google ads       8         5     2022
# 1  1596.0     Instagram       7         3     2022
# 2  1596.0       Website      20         7     2022
# 3  2116.8  Facebook Ads      11         8     2022
# 4  1646.4  Facebook Ads      10         8     2022

# %%
#Show DataFrame info.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            996 non-null    int64
#  1   gender         996 non-null    object
#  2   city           996 non-null    object
#  3   product        996 non-null    object
#  4   price          996 non-null    int64
#  5   promotion      996 non-null    float64
#  6   final_price    996 non-null    int64
#  7   profit         996 non-null    float64
#  8   sales_channel  996 non-null    object
#  9   pd_day         996 non-null    int64
#  10  pd_month       996 non-null    int64
#  11  pd_year        996 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 93.5+ KB

# %%
#Describe DataFrame - numericals
data.describe().T
# Out:
#              count         mean         std     min     25%     50%     75%  \
# age          996.0    30.060241    5.214435    25.0    27.0    29.0    30.0
# price        996.0  2237.951807  436.045986  1900.0  1900.0  1900.0  2800.0
# promotion    996.0     0.055823    0.100532     0.0     0.0     0.0     0.1
# final_price  996.0  2081.646586  305.768493  1900.0  1900.0  1900.0  2240.0
# profit       996.0  1748.583133  256.845534  1596.0  1596.0  1596.0  1881.6
# pd_day       996.0    16.538153    7.318562     7.0    10.0    15.0    23.0
# pd_month     996.0     8.214859    2.978317     1.0     7.0     9.0    11.0
# pd_year      996.0  2022.000000    0.000000  2022.0  2022.0  2022.0  2022.0
#
#                 max
# age            45.0
# price        2800.0
# promotion       0.3
# final_price  2800.0
# profit       2352.0
# pd_day         31.0
# pd_month       12.0
# pd_year      2022.0

# %%
data['age'].value_counts()
# Out:
# 29    144
# 26    134
# 27    133
# 30    130
# 25    112
# 28    111
# 40     22
# 43     19
# 45     19
# 35     18
# 44     18
# 38     17
# 39     16
# 32     15
# 37     14
# 31     14
# 33     14
# 36     13
# 42     13
# 34     13
# 41      7
# Name: age, dtype: int64

# %%
def plot_numeric_data(data, columns):
    for column in columns:
        sns.histplot(data[column], bins=10)
        plt.title(f'Distribución de {column}')
        plt.xlabel(column)
        plt.ylabel('Frecuencia')
        plt.show()

# Llamada a la función
numeric_columns = ['age', 'price', 'promotion', 'final_price', 'profit']
plot_numeric_data(data, numeric_columns)

# %%
data_num = data[['age', 'price', 'promotion', 'final_price', 'price','profit']]

# %%
correlations_matrix = data_num.corr()
correlations_matrix
# Out:
#                   age     price  promotion  final_price     price    profit
# age          1.000000 -0.012145   0.024445    -0.039824 -0.012145 -0.039824
# price       -0.012145  1.000000   0.716452     0.766500  1.000000  0.766500
# promotion    0.024445  0.716452   1.000000     0.101107  0.716452  0.101107
# final_price -0.039824  0.766500   0.101107     1.000000  0.766500  1.000000
# price       -0.012145  1.000000   0.716452     0.766500  1.000000  0.766500
# profit      -0.039824  0.766500   0.101107     1.000000  0.766500  1.000000

# %%
corr_matrix=data_num.corr()  # default
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
grouped_data = data.groupby('age').agg({'profit': 'sum'}).reset_index()

sns.lineplot(x='age', y='profit', data=grouped_data)
plt.xlabel('Age')
plt.ylabel('Total Profit')
plt.title('Total Profit by Age')
plt.show()

# %%
sns.lineplot(x='age', y='profit', data=data)
plt.show()

# %%
sns.barplot(x="profit", y="age", data=data, palette="viridis")
plt.show()

# %%
#Describe DataFrame - categoricals
data.describe(include=[np.object]).T
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_86436\2081608572.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.describe(include=[np.object]).T
#               count unique            top freq
# gender          996      2              F  682
# city            996     10    Guadalajara  228
# product         996      2           Rubí  622
# sales_channel   996      8  Instagram Ads  251

# %%
data['city'].value_counts()
# Out:
# Guadalajara         228
# Ciudad de México    145
# Aguascalientes      145
# Puebla               79
# Monterrey            71
# Zacatecas            68
# San Luis             67
# Tijuana              67
# Sinaloa              66
# Veracruz             60
# Name: city, dtype: int64

# %%
data['sales_channel'].value_counts()
# Out:
# Instagram Ads    251
# Facebook Ads     220
# Google ads       191
# Website          117
# Email             96
# Instagram         45
# Facebook          40
# Whatsapp          36
# Name: sales_channel, dtype: int64

# %%
columns = ['gender', 'city', 'product', 'sales_channel']

def plot_countplot(column):
    sns.countplot(x=column, data=data, palette="viridis")
    plt.xticks(rotation=45, ha='right', fontsize=8)  
    plt.tight_layout()  
    plt.show()

for column in columns:
    plot_countplot(column)

# %%
grouped_city = data.groupby('city').agg({'profit': ['mean', 'median', 'max', 'min']})
grouped_city = grouped_city.round(2)
grouped_city
# Out:
#                    profit
#                      mean  median     max     min
# city
# Aguascalientes    1732.72  1596.0  2352.0  1596.0
# Ciudad de México  1728.55  1596.0  2352.0  1596.0
# Guadalajara       1748.31  1596.0  2352.0  1596.0
# Monterrey         1755.48  1596.0  2352.0  1596.0
# Puebla            1796.32  1596.0  2352.0  1596.0
# San Luis          1766.76  1596.0  2352.0  1596.0
# Sinaloa           1769.85  1596.0  2352.0  1596.0
# Tijuana           1736.92  1596.0  2352.0  1596.0
# Veracruz          1791.16  1596.0  2352.0  1596.0
# Zacatecas         1698.78  1596.0  2352.0  1596.0

# %%
grouped_channel = data.groupby('sales_channel').agg({'sales_channel': 'count', 'profit': 'sum'})
grouped_channel = grouped_channel.round(2)
grouped_channel.columns = ['total_per_channel','profit']
grouped_channel
# Out:
#                total_per_channel    profit
# sales_channel
# Email                         96  170268.0
# Facebook                      40   69249.6
# Facebook Ads                 220  386786.4
# Google ads                   191  331363.2
# Instagram                     45   77666.4
# Instagram Ads                251  439656.0
# Website                      117  203532.0
# Whatsapp                      36   63067.2

# %%
grouped_channel = data.groupby('sales_channel').agg({'profit': 'sum'}).reset_index()

sns.barplot(x='sales_channel', y='profit', data=grouped_channel, palette="viridis" )
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.xlabel('Sales Channel')
plt.ylabel('Total Profit')
plt.title('Total Profit by Sales Channel')
plt.show()

# %%
segmented_data = data.groupby('age')['product'].value_counts().unstack().fillna(0)
segmented_data
# Out:
# product  Diamante  Rubí
# age
# 25             45    67
# 26             48    86
# 27             36    97
# 28             50    61
# 29             59    85
# 30             53    77
# 31              3    11
# 32              9     6
# 33              3    11
# 34              1    12
# 35              9     9
# 36              5     8
# 37              7     7
# 38              7    10
# 39              6    10
# 40              9    13
# 41              4     3
# 42              4     9
# 43              3    16
# 44              8    10
# 45              5    14

# %%
segmented_data.max()
# Out:
# product
# Diamante    59
# Rubí        97
# dtype: int64

# %%
count_product = data.groupby('product')['profit'].sum()
print(count_product)
# Out:
# product
# Diamante    748876.8
# Rubí        992712.0
# Name: profit, dtype: float64

# %%
profit_sum = data.groupby('product')['profit'].sum().reset_index()

sns.barplot(x="product", y="profit", data=profit_sum, palette="viridis")
plt.xlabel("Product")
plt.ylabel("Profit")
plt.title("Comparison of Count Product and Profit")
plt.show()

# %%
data1 = data.drop(['pd_day', 'pd_year', 'pd_month'], axis=1)
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 12))
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for i, column in enumerate(data1.columns):
    ax = axes[i // 3, i % 3]
    data[column].hist(ax=ax, bins=40)
    ax.set_title(column)

plt.show()

# %%
data=data.drop(['pd_day','pd_year','pd_month'], axis=1)
sns.pairplot(data)
