# %%
import pandas as pd
import numpy as np
import pymysql                        
from sqlalchemy import create_engine  
from getpass import getpass
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
password = getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/lia_fb'
engine = create_engine(connection_string)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
data = pd.read_sql_query('SELECT * FROM lia_fb', engine)
data.head()
# Out:
#    daily_followers  total_followers  posts_reach  share  impressions  clicks  \
# 0               85             6589         3506     83        19276      80
# 1               35             6624         2957    211         5201     509
# 2               89             6713         3611    117        15283     208
# 3               76             6789         2353    288         8048     115
# 4               50             6839         3498    294        17463      79
#
#   reactions  direct_messages  positive_comments  negative_comment  day  week  \
# 0      HAHA               21                285                87    7     1
# 1       Sad               26                295                93    7     6
# 2      Like               18                317                94    7    10
# 3      Care               32                324                99    7    14
# 4      Like               21                364               102    7    18
#
#    month
# 0      1
# 1      2
# ...

# %%
#Show DataFrame info.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   daily_followers    181 non-null    int64
#  1   total_followers    181 non-null    int64
#  2   posts_reach        181 non-null    int64
#  3   share              181 non-null    int64
#  4   impressions        181 non-null    int64
#  5   clicks             181 non-null    int64
#  6   reactions          181 non-null    object
#  7   direct_messages    181 non-null    int64
#  8   positive_comments  181 non-null    int64
#  9   negative_comment   181 non-null    int64
#  10  day                181 non-null    int64
#  11  week               181 non-null    int64
#  12  month              181 non-null    int64
# dtypes: int64(12), object(1)
# memory usage: 18.5+ KB

# %%
#Describe DataFrame - numericals
data.describe().T
# Out:
#                    count          mean          std     min     25%      50%  \
# daily_followers    181.0     61.204420    25.340727    20.0    39.0     61.0
# total_followers    181.0  12101.922652  3236.029966  6589.0  9303.0  12106.0
# posts_reach        181.0   2471.928177  1284.650177   232.0  1198.0   2503.0
# share              181.0    180.149171    95.504420    21.0    93.0    188.0
# impressions        181.0  10920.049724  5523.742921  1104.0  6144.0  11106.0
# clicks             181.0    307.149171   164.214646    50.0   163.0    305.0
# direct_messages    181.0     26.928177    11.142528     8.0    17.0     27.0
# positive_comments  181.0   2716.773481  1497.150712   285.0  1357.0   2817.0
# negative_comment   181.0    425.541436   196.374061    87.0   257.0    437.0
# day                181.0     16.834254     7.372256     7.0    10.0     16.0
# week               181.0     34.254144    13.354215     1.0    28.0     37.0
# ...

# %%
data.nunique()
# Out:
# daily_followers       76
# total_followers      181
# posts_reach          176
# share                140
# impressions          181
# clicks               161
# reactions              7
# direct_messages       39
# positive_comments    181
# negative_comment     181
# day                   25
# week                  35
# month                 12
# dtype: int64

# %%
data.shape
# Out:
# (181, 13)

# %%
plt.hist(data['daily_followers'], bins=30)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma')
plt.show()

# %%
positive_count = data['positive_comments'].sum()
negative_count = data['negative_comment'].sum()

count_data = pd.DataFrame({'Type': ['Positive Comments', 'Negative Comments'],
                           'Count': [positive_count, negative_count]})

sns.barplot(x='Type', y='Count', data=count_data, palette='viridis')
plt.xlabel('Comment Type')
plt.ylabel('Count')
plt.title('Comments Count')
plt.show()

# %%
posts_reach_sum = data['posts_reach'].sum()
impressions_sum = data['impressions'].sum()
share_sum = data['share'].sum()

totals_data = pd.DataFrame({'Metric': ['Posts Reach', 'Impressions', 'share'],
                            'Total': [posts_reach_sum, impressions_sum, share_sum]})

sns.barplot(x='Metric', y='Total', data=totals_data, palette='viridis')
plt.xlabel('Metric')
plt.ylabel('Total')
plt.title('Instagram Metrics')
plt.show()

# %%
positive_max = data['positive_comments'].max()
positive_max
# Out:
# 5280

# %%
negative_max = data['negative_comment'].max()
negative_max
# Out:
# 755

# %%
corr_matrix = data.drop(['day', 'week', 'month'], axis=1).corr()
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()
# Out:
# C:\Users\Andrea\AppData\Local\Temp\ipykernel_86756\3571011156.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.drop(['day', 'week', 'month'], axis=1).corr()

# %% [markdown]
# # Performance definition by database
#
# I'll compare the performance of organic platforms in base on sales and profit.
#
# For this analysis, we take into consideration the following variables:
# * Num. of sales
# * Percentage of sales based on the amount of received messages
# * Profit
# * Percentage of the profit in base of total profit
#
# The profit measure is the the Customer dataset.

# %%
print('The number of direct messages from Facebook are:', data['direct_messages'].sum())
# Out:
# The number of direct messages from Facebook are: 4874

# %%
Total_dm_f = 4874
Total_sales_f = 40

# %%
Convertion_rate_f = (Total_sales_f * 100)/ Total_dm_f
Convertion_rate_f
# Out:
# 0.8206811653672548

# %%
Profit_f = 69249.6
Total_profit = 380251.2

# %%
Porc_Profit_f = (Profit_f * 100)/ Total_profit
Porc_Profit_f
# Out:
# 18.211540160820007

# %%
Proft_per_f_sale = Profit_f /Total_sales_f
Proft_per_f_sale
# Out:
# 1731.2400000000002

# %%
data1 = {'Total_dm_f': [4874],
         'Total_sales_f':[40],
        'Convertion_rate_f': [0.82],
        'Profit_f': [69249.6],
        'Total_profit': [380251.20],
        'Porc_Profit_f':[18.21],
        'Proft_per_f_sale': [1731.24]}

performance_org_f = pd.DataFrame(data1)
performance_org_f
# Out:
#    Total_dm_f  Total_sales_f  Convertion_rate_f  Profit_f  Total_profit  \
# 0        4874             40               0.82   69249.6      380251.2
#
#    Porc_Profit_f  Proft_per_f_sale
# 0          18.21           1731.24

# %%
#save my new database

performance_org_f.to_csv('performance_org_f.csv', index=False)
